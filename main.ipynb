# %% [markdown]
# # 数据读取
#
# 比赛地址: https://aistudio.baidu.com/aistudio/competition/detail/1022/0/introduction

# %%
# !unzip train_datasets.zip
# Out:
# Archive:  train_datasets.zip
#    creating: train_datasets/
#   inflating: __MACOSX/._train_datasets
#    creating: train_datasets/groundtruth/
#   inflating: __MACOSX/train_datasets/._groundtruth
#    creating: train_datasets/image/
#   inflating: __MACOSX/train_datasets/._image
#   inflating: train_datasets/._groundtruth
#   inflating: train_datasets/._image
#   inflating: train_datasets/groundtruth/RjgThxL4Xc.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._RjgThxL4Xc.jpg
#   inflating: train_datasets/groundtruth/SzvRVIW6ac.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._SzvRVIW6ac.jpg
#   inflating: train_datasets/groundtruth/QVvrmgnLki.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._QVvrmgnLki.jpg
#   inflating: train_datasets/groundtruth/ymcOT2J93Y.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._ymcOT2J93Y.jpg
#   inflating: train_datasets/groundtruth/Y0ug7flEBP.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._Y0ug7flEBP.jpg
#   inflating: train_datasets/groundtruth/t2OaFozxjv.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._t2OaFozxjv.jpg
#   inflating: train_datasets/groundtruth/4ogUwRuQyF.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._4ogUwRuQyF.jpg
#   inflating: train_datasets/groundtruth/4YQ2DJK7PI.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._4YQ2DJK7PI.jpg
#   inflating: train_datasets/groundtruth/0ROCpdD7kH.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._0ROCpdD7kH.jpg
#   inflating: train_datasets/groundtruth/jLiqPT8Plg.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._jLiqPT8Plg.jpg
#   inflating: train_datasets/groundtruth/WfQgEUtDhT.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._WfQgEUtDhT.jpg
#   inflating: train_datasets/groundtruth/iSfVoLCTnw.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._iSfVoLCTnw.jpg
#   inflating: train_datasets/groundtruth/xn7N5fuzUC.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._xn7N5fuzUC.jpg
#   inflating: train_datasets/groundtruth/c0Rk07MtdJ.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._c0Rk07MtdJ.jpg
#   inflating: train_datasets/groundtruth/JWkzoF5tt1.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._JWkzoF5tt1.jpg
#   inflating: train_datasets/groundtruth/rnQf2Abxoi.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._rnQf2Abxoi.jpg
#   inflating: train_datasets/groundtruth/8jCj8gu35s.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._8jCj8gu35s.jpg
#   inflating: train_datasets/groundtruth/UZAbiRDpG2.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._UZAbiRDpG2.jpg
#   inflating: train_datasets/groundtruth/Rg8WnDT7he.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._Rg8WnDT7he.jpg
#   inflating: train_datasets/groundtruth/5ZAGH8ETwe.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._5ZAGH8ETwe.jpg
#   inflating: train_datasets/groundtruth/Y4Y4gBG0b8.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._Y4Y4gBG0b8.jpg
#   inflating: train_datasets/groundtruth/YcUlF6RwTu.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._YcUlF6RwTu.jpg
#   inflating: train_datasets/groundtruth/UQA5PeMPar.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._UQA5PeMPar.jpg
#   inflating: train_datasets/groundtruth/HexdNKIMKZ.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._HexdNKIMKZ.jpg
#   inflating: train_datasets/groundtruth/HDT7JNgZct.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._HDT7JNgZct.jpg
#   inflating: train_datasets/groundtruth/9JVD3Gaepi.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._9JVD3Gaepi.jpg
#   inflating: train_datasets/groundtruth/iFQ6xRjXEt.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._iFQ6xRjXEt.jpg
#   inflating: train_datasets/groundtruth/3Yh3dzztiQ.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._3Yh3dzztiQ.jpg
#   inflating: train_datasets/groundtruth/QlAbKWsv7H.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._
jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._LInK9W3ExC.jpg
#   inflating: train_datasets/groundtruth/fzHdVObhbv.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._fzHdVObhbv.jpg
#   inflating: train_datasets/groundtruth/B0ae8NxqQT.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._B0ae8NxqQT.jpg
#   inflating: train_datasets/groundtruth/0VxLkN0XJr.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._0VxLkN0XJr.jpg
#   inflating: train_datasets/groundtruth/9Q3UVoSx0G.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._9Q3UVoSx0G.jpg
#   inflating: train_datasets/groundtruth/fRsK1GunDA.jpg
#   inflating: __MACOSX/train_datasets/groundtruth/._fRsK1GunDA.jpg
# ...
#   inflating: train_datasets/image/._wkSBszWXYw.jpg
#   inflating: train_datasets/image/._eu5xK6daVF.jpg
#   inflating: train_datasets/image/._MctugoCBcb.jpg
#   inflating: train_datasets/image/._Mbv93M9pjp.jpg
#   inflating: train_datasets/image/._FEeG4cKHqy.jpg
#   inflating: train_datasets/image/._mA8in7YQLg.jpg
#   inflating: train_datasets/image/._qZNGEkmj2B.jpg
#   inflating: train_datasets/image/._JSxIXlUzNM.jpg
#   inflating: train_datasets/image/._p5MgXDPzGt.jpg
#   inflating: train_datasets/image/._HrUff1qDYQ.jpg
#   inflating: train_datasets/image/._tV6bzp3S4m.jpg
#   inflating: train_datasets/image/._oaFhdo6Ddl.jpg
#   inflating: train_datasets/image/._0qgMXF0rH9.jpg
#   inflating: train_datasets/image/._b7qM1ZQ6A8.jpg
#   inflating: train_datasets/image/._DoBJCapjp9.jpg
#   inflating: train_datasets/image/._MNafmrbnPC.jpg
#   inflating: train_datasets/image/._tH0Be7L7iL.jpg
#   inflating: train_datasets/image/._LqZO83mCWq.jpg
#   inflating: train_datasets/image/._MFZlJMNA7z.jpg
#   inflating: train_datasets/image/._HqbwOlLTPP.jpg
#   inflating: train_datasets/image/._g5IpOnrfCh.jpg
#   inflating: train_datasets/image/._WZSBr7NHWm.jpg
#   inflating: train_datasets/image/._nbE6ndWFnu.jpg
#   inflating: train_datasets/image/._pny208zUNV.jpg
#   inflating: train_datasets/image/._3TKKpKEKLr.jpg
#   inflating: train_datasets/image/._lbFJZj9cpK.jpg
#   inflating: train_datasets/image/._y1uHjIsNJm.jpg
#   inflating: train_datasets/image/._4qsvQju4mX.jpg
#   inflating: train_datasets/image/._qPaRYS3sRt.jpg
#   inflating: train_datasets/image/._tJ7XiU4UH2.jpg
#   inflating: train_datasets/image/._xPyjfpY0Dg.jpg
#   inflating: train_datasets/image/._P0pM2uIicb.jpg
#   inflating: train_datasets/image/._r50kU8Wr5s.jpg
#   inflating: train_datasets/image/._dgt4uEbwYX.jpg
#   inflating: train_datasets/image/._foGC7elctS.jpg
#   inflating: train_datasets/image/._uxXDW6Jdcn.jpg
#   inflating: train_datasets/image/._BAuGNzk58T.jpg
#   inflating: train_datasets/image/._liCk0moAqC.jpg
#   inflating: train_datasets/image/._ImnGED3sGS.jpg
#   inflating: train_datasets/image/._Ojaj9yveDv.jpg
#   inflating: train_datasets/image/._QKprXuerSq.jpg
#   inflating: train_datasets/image/._yx216FZpzt.jpg
#   inflating: train_datasets/image/._y4mI8Q4XcN.jpg
#   inflating: train_datasets/image/._Cfnvf645WD.jpg
#   inflating: train_datasets/image/._ylpLPqoTe3.jpg
#   inflating: train_datasets/image/._SaYbKUYmK2.jpg
#   inflating: train_datasets/image/._vWrRxnyCLK.jpg
#   inflating: train_datasets/image/._GgkCeopv8L.jpg
#   inflating: train_datasets/image/._xzf4FqQOjn.jpg
#   inflating: train_datasets/image/._ttsvn01uF2.jpg
#   inflating: train_datasets/image/._DvvOs2U4eH.jpg
#   inflating: train_datasets/image/._k2kQYh2LBt.jpg
#   inflating: train_datasets/image/._LN3kkC6WXV.jpg
#   inflating: train_datasets/image/._3Ykak8sr6l.jpg
#   inflating: train_datasets/image/._mYXPGLgJTz.jpg
#   inflating: train_datasets/image/._Hx4pVKitTV.jpg
#   inflating: train_datasets/image/._ZRGzK076mr.jpg
#   inflating: train_datasets/image/._pWthU6L3rg.jpg
#   inflating: train_datasets/image/._I93LyxVtEM.jpg
#   inflating: train_datasets/image/._L8Cdvgaso4.jpg
#   inflating: train_datasets/image/._uhNjOTcXZH.jpg
#   inflating: train_datasets/image/._c4o30Hc3h8.jpg
#   inflating: train_datasets/image/._gYkXf8sL8z.jpg
#   inflating: train_datasets/image/._4Zu1IdMeFD.jpg
#   inflating: train_datasets/image/._iNF2HF0Zqb.jpg
#   inflating: train_datasets/image/._W9571hySQy.jpg
#   inflating: train_datasets/image/._BYrYjyvmbD.jpg
#   inflating: train_datasets/image/._6SiswEaR11.jpg
#   inflating: train_datasets/image/._W3cKf9kuR3.jpg
#   inflating: train_datasets/image/._SsLNjNTb9n.jpg
#   inflating: train_datasets/image/._uT09KoBeMC.jpg
#   inflating: train_datasets/image/._1Ae0fnp5Dc.jpg
#   inflating: train_datasets/image/._y50R1uwnyr.jpg
#   inflating: train_datasets/image/._PWCAfKQm0S.jpg
#   inflating: train_datasets/image/._5BAicWD40W.jpg
#   inflating: train_datasets/image/._3LmPw6bIlx.jpg
#   inflating: train_datasets/image/._pfUcPQyS1D.jpg
#   inflating: train_datasets/image/._fFzxwmJI92.jpg
#   inflating: train_datasets/image/._wgekAXyiCd.jpg
#   inflating: train_datasets/image/._nuFTnNnhyQ.jpg
#   inflating: train_datasets/image/._RPZq3sDvgs.jpg
#   inflating: train_datasets/image/._LcGBASCaCC.jpg
#   inflating: train_datasets/image/._Vm3tQhs7mq.jpg
#   inflating: train_datasets/image/._Bfz2bGurkY.jpg
#   inflating: train_datasets/image/._1HbDO0iZhU.jpg
#   inflating: train_datasets/image/._Xz2b3vdo1S.jpg
#   inflating: train_datasets/image/._ZmDpnhYSFp.jpg
#   inflating: train_datasets/image/._fs7QSelc68.jpg
#   inflating: train_datasets/image/._OagKjeZ8qT.jpg
#   inflating: train_datasets/image/._OxjI8RDVdU.jpg
#   inflating: train_datasets/image/._a785gN7OcN.jpg
#   inflating: train_datasets/image/._qxshUrsvha.jpg
#   inflating: train_datasets/image/._RHNabwvQ1C.jpg
#   inflating: train_datasets/image/._S9Mg7tJVBQ.jpg
#   inflating: train_datasets/image/._wxQD4kE4qI.jpg
#   inflating: train_datasets/image/._SFFS3wlJn4.jpg
#   inflating: train_datasets/image/._PCHyrbwDnd.jpg
#   inflating: train_datasets/image/._9NG11eT91Z.jpg
#   inflating: train_datasets/image/._q3EVJ2GgFf.jpg
#   inflating: train_datasets/image/._pEesQO4yHL.jpg
#   inflating: train_datasets/image/._g0lyivEKtI.jpg
#   inflating: train_datasets/image/._UXrgpPFTgJ.jpg
#   inflating: train_datasets/image/._D2k6ik6s68.jpg
#   inflating: train_datasets/image/._JJ4riqodG7.jpg
#   inflating: train_datasets/image/._aB0x8A6s18.jpg
#   inflating: train_datasets/image/._0HMHM9lHAN.jpg
#   inflating: train_datasets/image/._EaOyxi0y8y.jpg
#   inflating: train_datasets/image/._XUJ3e97kpe.jpg
#   inflating: train_datasets/image/._A0gJb30UgA.jpg
#   inflating: train_datasets/image/._kcDA2owBy7.jpg
#   inflating: train_datasets/image/._oCdpR0BJCZ.jpg
#   inflating: train_datasets/image/._4axEoXrOon.jpg
#   inflating: train_datasets/image/._z2CjGMZzNb.jpg
#   inflating: train_datasets/image/._HxJwF2roUL.jpg
#   inflating: train_datasets/image/._zymvdmXKrq.jpg
#   inflating: train_datasets/image/._Q92hJX6tkR.jpg
#   inflating: train_datasets/image/._rMNhkBgtHg.jpg
#   inflating: train_datasets/image/._vBiF2mmYY6.jpg
#   inflating: train_datasets/image/._98jtmhTkrP.jpg
#   inflating: train_datasets/image/._kRMczpxVka.jpg
#   inflating: train_datasets/image/._xr2t4wcnJe.jpg
#   inflating: train_datasets/image/._jCb6mJBfJd.jpg
#   inflating: train_datasets/image/._tMEGwuARpO.jpg
#   inflating: train_datasets/image/._uIwiGaDJCZ.jpg
#   inflating: train_datasets/image/._JRdXcQtPvD.jpg
#   inflating: train_datasets/image/._VaV6wng7Wr.jpg
#   inflating: train_datasets/image/._QQhfW9YCQD.jpg
#   inflating: train_datasets/image/._Bah0ntFyuu.jpg
#   inflating: train_datasets/image/._dqLjdfsb2v.jpg
#   inflating: train_datasets/image/._swsfETqGV4.jpg
#   inflating: train_datasets/image/._USeHLyRAHI.jpg
#   inflating: train_datasets/image/._IeoqhkW44z.jpg
#   inflating: train_datasets/image/._rEUdQjBEy6.jpg
#   inflating: train_datasets/image/._YCOawgPkay.jpg
#   inflating: train_datasets/image/._oCpUF9ett5.jpg
#   inflating: train_datasets/image/._OH4BIbrjdj.jpg
#   inflating: train_datasets/image/._A1rCVilbdI.jpg
#   inflating: train_datasets/image/._brlV068BCF.jpg
#   inflating: train_datasets/image/._CZfP2xdSlz.jpg
#   inflating: train_datasets/image/._zwr3oJUwje.jpg
#   inflating: train_datasets/image/._IczbasYnWz.jpg
#   inflating: train_datasets/image/._Tz95FX34vr.jpg
#   inflating: train_datasets/image/._T8iTRpSM8f.jpg
#   inflating: train_datasets/image/._oG2wgnxsG2.jpg
#   inflating: train_datasets/image/._f77Kp4zr0F.jpg
#   inflating: train_datasets/image/._oYDl416KLq.jpg
#   inflating: train_datasets/image/._US4q6i32ig.jpg
#   inflating: train_datasets/image/._K9MT6rFpCD.jpg
#   inflating: train_datasets/image/._iQTRNQecvg.jpg
#   inflating: train_datasets/image/._hamXIcvcfM.jpg
#   inflating: train_datasets/image/._lFYBWhrDyc.jpg
#   inflating: train_datasets/image/._BkxQ5kleas.jpg
#   inflating: train_datasets/image/._IU81iiEjI7.jpg
#   inflating: train_datasets/image/._OCDLJC6ozi.jpg
#   inflating: train_datasets/image/._gfUTtOyKMu.jpg
#   inflating: train_datasets/image/._I7kYpzfajy.jpg
#   inflating: train_datasets/image/._XNGYwbw9i2.jpg
#   inflating: train_datasets/image/._3wn0gUvVin.jpg
#   inflating: train_datasets/image/._L0n9UJy7pX.jpg
#   inflating: train_datasets/image/._58iPuBIwwX.jpg
#   inflating: train_datasets/image/._GouC3ax4pO.jpg
#   inflating: train_datasets/image/._aTjQyWJkfR.jpg
#   inflating: train_datasets/image/._MsVNC5HiQc.jpg
#   inflating: train_datasets/image/._GnVU7LZm64.jpg
#   inflating: train_datasets/image/._86l3VksT3l.jpg
#   inflating: train_datasets/image/._2mvIcKu1O8.jpg
#   inflating: train_datasets/image/._VsjG5T2Zn0.jpg
#   inflating: train_datasets/image/._FG5DJLDAsP.jpg
#   inflating: train_datasets/image/._gt9Q0cFIyg.jpg
#   inflating: train_datasets/image/._ncAI88el5E.jpg
#   inflating: train_datasets/image/._UVFVzmBlsE.jpg
#   inflating: train_datasets/image/._f1g2gaSczx.jpg
#   inflating: train_datasets/image/._mQQDR7wXLn.jpg
#   inflating: train_datasets/image/._vEVBuPmSd3.jpg
#   inflating: train_datasets/image/._ZFGBdRMZmF.jpg
#   inflating: train_datasets/image/._9Tk0aw7WN1.jpg
#   inflating: train_datasets/image/._jz56DbEY73.jpg
#   inflating: train_datasets/image/._NTiTnbURYT.jpg
#   inflating: train_datasets/image/._Egikc2Rtup.jpg
#   inflating: train_datasets/image/._fXhpQ4P8BW.jpg
#   inflating: train_datasets/image/._0HtVKkYM1J.jpg
#   inflating: train_datasets/image/._c8PMMnieeN.jpg
#   inflating: train_datasets/image/._4L3rKDFjfh.jpg
#   inflating: train_datasets/image/._KAdLxiftnM.jpg
#   inflating: train_datasets/image/._gywXuGKrMI.jpg
#   inflating: train_datasets/image/._fqHk4VafZy.jpg
#   inflating: train_datasets/image/._HTp84pBcCI.jpg
#   inflating: train_datasets/image/._u2IIyCa2bA.jpg
#   inflating: train_datasets/image/._6ZIVGqZD6w.jpg
#   inflating: train_datasets/image/._kBLJfdO06r.jpg
#   inflating: train_datasets/image/._0sl5SqtWw8.jpg
#   inflating: train_datasets/image/._pJUPXQPsEP.jpg
#   inflating: train_datasets/image/._DsEITZ2h2M.jpg
#   inflating: train_datasets/image/._WQ3UKybxqr.jpg
#   inflating: train_datasets/image/._wGhvhYGwCP.jpg
#   inflating: train_datasets/image/._sNDxvIJW9X.jpg
#   inflating: train_datasets/image/._70c9sDiNWS.jpg
#   inflating: train_datasets/image/._83COB3aIxU.jpg
#   inflating: train_datasets/image/._03ZQAOlBfQ.jpg
#   inflating: train_datasets/image/._jkjqVRQjgN.jpg
#   inflating: train_datasets/image/._Pl2MrLUTxe.jpg
#   inflating: train_datasets/image/._8N2UkUxQlf.jpg
#   inflating: train_datasets/image/._znWDAOZMcZ.jpg
#   inflating: train_datasets/image/._ZdXQ5OC0vg.jpg
#   inflating: train_datasets/image/._OF3rhwBWLK.jpg
#   inflating: train_datasets/image/._FVpyUVMqQ7.jpg
#   inflating: train_datasets/image/._uRM0eNGNX5.jpg
#   inflating: train_datasets/image/._r6Sop7Vy67.jpg
#   inflating: train_datasets/image/._2IpyAD7i32.jpg
#   inflating: train_datasets/image/._OatrTf4Xa9.jpg
#   inflating: train_datasets/image/._QTAh1F336E.jpg
#   inflating: train_datasets/image/._4Zm8u0JrsE.jpg
#   inflating: train_datasets/image/._tLqzg7A8eD.jpg
#   inflating: train_datasets/image/._vIikeVsBcm.jpg
#   inflating: train_datasets/image/._35rZoiZZ68.jpg
#   inflating: train_datasets/image/._2NHegnTUhV.jpg
#   inflating: train_datasets/image/._gLp892d4vI.jpg
#   inflating: train_datasets/image/._QZF4GAbpSx.jpg
#   inflating: train_datasets/image/._xJ569cG0P3.jpg
#   inflating: train_datasets/image/._ZyvJcabwNx.jpg
#   inflating: train_datasets/image/._Lkn3Dw7V6v.jpg
#   inflating: train_datasets/image/._CeQNBmF91G.jpg
#   inflating: train_datasets/image/._J0lAKwUzU6.jpg
#   inflating: train_datasets/image/._x7VtKDHjAQ.jpg
#   inflating: train_datasets/image/._tgn1F63Kpz.jpg
#   inflating: train_datasets/image/._EfN0d6ZXpB.jpg
#   inflating: train_datasets/image/._h4FmZi4RuQ.jpg
#   inflating: train_datasets/image/._BhReVuHDEx.jpg
#   inflating: train_datasets/image/._udNJISXV1T.jpg
#   inflating: train_datasets/image/._1fOko08Gst.jpg
#   inflating: train_datasets/image/._xX9vY66aOb.jpg
#   inflating: train_datasets/image/._Q9u3utNqgA.jpg
#   inflating: train_datasets/image/._lcK3EOG1cc.jpg
#   inflating: train_datasets/image/._h2dQCkINOO.jpg
#   inflating: train_datasets/image/._QyIRvpW9Lv.jpg
#   inflating: train_datasets/image/._F7t9EBHjhc.jpg
#   inflating: train_datasets/image/._xQ30oRnC82.jpg
#   inflating: train_datasets/image/._8izNw04bhD.jpg
#   inflating: train_datasets/image/._t07mJxOTgM.jpg
#   inflating: train_datasets/image/._de0qX9K7nn.jpg
#   inflating: train_datasets/image/._lNPkZacS9W.jpg
#   inflating: train_datasets/image/._5ATdZl8IIr.jpg
#   inflating: train_datasets/image/._Dvnru1o2ku.jpg
#   inflating: train_datasets/image/._aXbyu01aFQ.jpg
#   inflating: train_datasets/image/._MNodBPpMDW.jpg
#   inflating: train_datasets/image/._8krOtNCJj4.jpg
#   inflating: train_datasets/image/._KsC1cYEqGn.jpg
#   inflating: train_datasets/image/._L6qmE38p3N.jpg
#   inflating: train_datasets/image/._JHw0betsfz.jpg
#   inflating: train_datasets/image/._tJgZlBKKmW.jpg
#   inflating: train_datasets/image/._jyQoCnYHAG.jpg
#   inflating: train_datasets/image/._2Iph88tBwA.jpg
#   inflating: train_datasets/image/._la5NXs3ibD.jpg
#   inflating: train_datasets/image/._YN1tIDJR1J.jpg
#   inflating: train_datasets/image/._93NkjZAWKB.jpg
#   inflating: train_datasets/image/._qvEjEWwQER.jpg
#   inflating: train_datasets/image/._jYy4XXJb4e.jpg
#   inflating: train_datasets/image/._D8SNLI3oin.jpg
#   inflating: train_datasets/image/._8uzzTYAnv7.jpg
#   inflating: train_datasets/image/._obbhPtMYPb.jpg
#   inflating: train_datasets/image/._MK5xysunfE.jpg
#   inflating: train_datasets/image/._bqNOqChi60.jpg
#   inflating: train_datasets/image/._vEPKIF8FpQ.jpg
#   inflating: train_datasets/image/._2JC9ZZNwjN.jpg
#   inflating: train_datasets/image/._qHzNtnVJCx.jpg
#   inflating: train_datasets/image/._W194s3hCbL.jpg
#   inflating: train_datasets/image/._rhrjlng0HA.jpg
#   inflating: train_datasets/image/._jE0F51Gv2Q.jpg
#   inflating: train_datasets/image/._xfa0xcuRTO.jpg
#   inflating: train_datasets/image/._3BMzktpBdi.jpg
#   inflating: train_datasets/image/._3EYRTojwrp.jpg
#   inflating: train_datasets/image/._1w2ehuGazR.jpg
#   inflating: train_datasets/image/._GcfSkstICA.jpg
#   inflating: train_datasets/image/._jF76ZmbxXR.jpg
#   inflating: train_datasets/image/._NCQmXI9mqq.jpg
#   inflating: train_datasets/image/._cTfGEWHI3H.jpg
#   inflating: train_datasets/image/._EX0XV2cRhR.jpg
#   inflating: train_datasets/image/._KgUu8g5QZP.jpg
#   inflating: train_datasets/image/._SQTPHpFMbA.jpg
#   inflating: train_datasets/image/._6Uja7W4fzJ.jpg
#   inflating: train_datasets/image/._AyfnY3mzjl.jpg
#   inflating: train_datasets/image/._nPKW2qmM8f.jpg
#   inflating: train_datasets/image/._bgdSdVlw6D.jpg
#   inflating: train_datasets/image/._5xf3QU0gA4.jpg
#   inflating: train_datasets/image/._bLHBLYY24J.jpg
#   inflating: train_datasets/image/._IpHdKLFaXD.jpg
#   inflating: train_datasets/image/._8xGwPVfdPX.jpg
#   inflating: train_datasets/image/._SYkpQ7LgaB.jpg
#   inflating: train_datasets/image/._A0PjC2PyMs.jpg
#   inflating: train_datasets/image/._8A6VxdNDK5.jpg
#   inflating: train_datasets/image/._whlyXsa4Rp.jpg
#   inflating: train_datasets/image/._07fBAqO8xn.jpg
#   inflating: train_datasets/image/._hNCg73HQny.jpg
#   inflating: train_datasets/image/._R9Lu3Aiz0u.jpg
#   inflating: train_datasets/image/._ecyWAwUTGk.jpg
#   inflating: train_datasets/image/._txZYGonDtu.jpg
#   inflating: train_datasets/image/._ZP81gVAuFB.jpg
#   inflating: train_datasets/image/._eODw5rXb21.jpg
#   inflating: train_datasets/image/._cZbIMDuA7M.jpg
#   inflating: train_datasets/image/._FX62tra9F0.jpg
#   inflating: train_datasets/image/._P9hJAgeeU1.jpg

# %%
# 导入需要的库
import paddle
import os
import numpy as np
import pandas as pd
import cv2
import paddle
import paddle.nn.functional as F
from paddle import nn

# %% [markdown]
# # 定义数据集

# %%
# 定义数据读取器
class MyDateset(paddle.io.Dataset):
    # 构造函数，初始化数据集
    # mode: 模式，'train'或者其他
    # watermark_dir: 水印图像的路径
    # bg_dir: 背景（或者说是标签）图像的路径
    def __init__(self, mode = 'train', watermark_dir = '/jinx/AIStudio/Beautifying/train_datasets/image/', bg_dir = '/jinx/AIStudio/Beautifying/train_datasets/groundtruth/'):
        # 调用父类的构造函数
        super(MyDateset, self).__init__()
        # 初始化模式
        self.mode = mode 
        # 初始化水印图像的路径, 有水印的图片就是有痘痘的图片
        self.watermark_dir = watermark_dir
        # 初始化背景图像的路径, 背景图片我们可以认为就是没有痘痘的图片
        self.bg_dir = bg_dir
        # 获取水印图像的文件列表
        self.train_list = os.listdir(self.watermark_dir)

    def __getitem__(self, index):
        # 获取每一个有痘痘的图片
        item = self.train_list[index]
        #print(item)
        bg_item = self.train_list[index]
        img = cv2.imread(self.watermark_dir+item)
        # 没痘痘的图片
        label = cv2.imread(self.bg_dir+bg_item)
        #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        #label = cv2.cvtColor(label, cv2.COLOR_BGR2RGB)
        # 图片放缩
        img = paddle.vision.transforms.resize(img, (512,512), interpolation='bilinear') # 有痘痘
        label = paddle.vision.transforms.resize(label, (512,512), interpolation='bilinear') # 没痘痘
        # 对图像进行转置，使其从HWC变为CHW
        img = img.transpose((2,0,1)) # (3,512,512)
        label = label.transpose((2,0,1)) # (3,512,512)
        # 将图像的像素值归一化到[0,1]
        img = img/255
        label = label/255
        # # 将numpy数组转为Paddle的Tensor，并设置数据类型为float32
        img = paddle.to_tensor(img).astype('float32')
        label = paddle.to_tensor(label).astype('float32')
        return img,label

    def __len__(self):
        return len(self.train_list)

# %% [markdown]
# # 定义网络

# %%
# 定义网络结构
class Encoder(nn.Layer):#下采样：两层卷积，两层归一化，最后池化。
    def __init__(self, num_channels, num_filters):
        super(Encoder,self).__init__()#继承父类的初始化
        self.conv1 = nn.Conv2D(in_channels=num_channels,
                              out_channels=num_filters,
                              kernel_size=3,#3x3卷积核，步长为1，填充为1，不改变图片尺寸[H W]
                              stride=1,
                              padding=1)
        self.bn1   = nn.BatchNorm(num_filters,act="relu")#归一化，并使用了激活函数
        
        self.conv2 = nn.Conv2D(in_channels=num_filters,
                              out_channels=num_filters,
                              kernel_size=3,
                              stride=1,
                              padding=1)
        self.bn2   = nn.BatchNorm(num_filters,act="relu")
        
        self.pool  = nn.MaxPool2D(kernel_size=2,stride=2,padding="SAME")#池化层，图片尺寸减半[H/2 W/2]
        
    def forward(self,inputs):
        x = self.conv1(inputs)
        x = self.bn1(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x_conv = x           #两个输出，灰色 ->
        x_pool = self.pool(x)#两个输出，红色 | 
        return x_conv, x_pool
    
class Decoder(nn.Layer):#上采样：一层反卷积，两层卷积层，两层归一化
    def __init__(self, num_channels, num_filters):
        super(Decoder,self).__init__()
        self.up = nn.Conv2DTranspose(in_channels=num_channels,
                                    out_channels=num_filters,
                                    kernel_size=2,
                                    stride=2,
                                    padding=0)#图片尺寸变大一倍[2*H 2*W]

        self.conv1 = nn.Conv2D(in_channels=num_filters*2,
                              out_channels=num_filters,
                              kernel_size=3,
                              stride=1,
                              padding=1)
        self.bn1   = nn.BatchNorm(num_filters,act="relu")
        
        self.conv2 = nn.Conv2D(in_channels=num_filters,
                              out_channels=num_filters,
                              kernel_size=3,
                              stride=1,
                              padding=1)
        self.bn2   = nn.BatchNorm(num_filters,act="relu")
        
    def forward(self,input_conv,input_pool):
        x = self.up(input_pool)
        h_diff = (input_conv.shape[2]-x.shape[2])
        w_diff = (input_conv.shape[3]-x.shape[3])
        pad = nn.Pad2D(padding=[h_diff//2, h_diff-h_diff//2, w_diff//2, w_diff-w_diff//2])
        x = pad(x)                                #以下采样保存的feature map为基准，填充上采样的feature map尺寸
        x = paddle.concat(x=[input_conv,x],axis=1)#考虑上下文信息，in_channels扩大两倍
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.conv2(x)
        x = self.bn2(x)
        return x
    
class UNet(nn.Layer):
    def __init__(self,num_classes=3):
        super(UNet,self).__init__()
        # (3,512,512)
        self.down1 = Encoder(num_channels=  3, num_filters=64) #下采样
        self.down2 = Encoder(num_channels= 64, num_filters=128)
        self.down3 = Encoder(num_channels=128, num_filters=256)
        self.down4 = Encoder(num_channels=256, num_filters=512)
        
        self.mid_conv1 = nn.Conv2D(512,1024,1)                 #中间层
        self.mid_bn1   = nn.BatchNorm(1024,act="relu")
        self.mid_conv2 = nn.Conv2D(1024,1024,1)
        self.mid_bn2   = nn.BatchNorm(1024,act="relu")

        self.up4 = Decoder(1024,512)                           #上采样
        self.up3 = Decoder(512,256)
        self.up2 = Decoder(256,128)
        self.up1 = Decoder(128,64)
        
        self.last_conv = nn.Conv2D(64,num_classes,1)           #1x1卷积，softmax做分类
        
    def forward(self,inputs):
        
        x1, x = self.down1(inputs) # (3,512,512)
        x2, x = self.down2(x)
        x3, x = self.down3(x)
        x4, x = self.down4(x)
        
        x = self.mid_conv1(x)
        x = self.mid_bn1(x)
        x = self.mid_conv2(x)
        x = self.mid_bn2(x)
        
        x = self.up4(x4, x)
        x = self.up3(x3, x)
        x = self.up2(x2, x)
        x = self.up1(x1, x)
        
        x = self.last_conv(x)
        
        return x

# %% [markdown]
# # Loss定义

# %%
# 定义loss
def gaussian1d(window_size, sigma):
    ###window_size = 11
    x = paddle.arange(window_size,dtype='float32')
    x = x - window_size//2
    gauss = paddle.exp(-x ** 2 / float(2 * sigma ** 2))
    # print('gauss.size():', gauss.size())
    ### torch.Size([11])
    return gauss / gauss.sum()

def create_window(window_size, sigma, channel):
    _1D_window = gaussian1d(window_size, sigma).unsqueeze(1)
    _2D_window = _1D_window.mm(_1D_window.t()).unsqueeze(0).unsqueeze(0)
    # print('2d',_2D_window.shape)
    # print(window_size, sigma, channel)
    return _2D_window.expand([channel,1,window_size,window_size])

def _ssim(img1, img2, window, window_size, channel=3 ,data_range = 255.,size_average=True,C=None):
    # size_average for different channel

    padding = window_size // 2

    mu1 = F.conv2d(img1, window, padding=padding, groups=channel)
    mu2 = F.conv2d(img2, window, padding=padding, groups=channel)
    # print(mu1.shape)
    # print(mu1[0,0])
    # print(mu1.mean())
    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1 * mu2
    sigma1_sq = F.conv2d(img1 * img1, window, padding=padding, groups=channel) - mu1_sq
    sigma2_sq = F.conv2d(img2 * img2, window, padding=padding, groups=channel) - mu2_sq
    sigma12 = F.conv2d(img1 * img2, window, padding=padding, groups=channel) - mu1_mu2
    if C ==None:
        C1 = (0.01*data_range) ** 2
        C2 = (0.03*data_range) ** 2
    else:
        C1 = (C[0]*data_range) ** 2
        C2 = (C[1]*data_range) ** 2
    # l = (2 * mu1_mu2 + C1) / (mu1_sq + mu2_sq + C1)
    # ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2))
    sc = (2 * sigma12 + C2) / (sigma1_sq + sigma2_sq + C2)
    lsc = ((2 * mu1_mu2 + C1) / (mu1_sq + mu2_sq + C1))*sc

    if size_average:
        ### ssim_map.mean()是对这个tensor里面的所有的数值求平均
        return lsc.mean()
    else:
        # ## 返回各个channel的值
        return lsc.flatten(2).mean(-1),sc.flatten(2).mean(-1)

def ms_ssim(
    img1, img2,window, data_range=255, size_average=True, window_size=11, channel=3, sigma=1.5, weights=None, C=(0.01, 0.03)
):

    r""" interface of ms-ssim
    Args:
        img1 (torch.Tensor): a batch of images, (N,C,[T,]H,W)
        img2 (torch.Tensor): a batch of images, (N,C,[T,]H,W)
        data_range (float or int, optional): value range of input images. (usually 1.0 or 255)
        size_average (bool, optional): if size_average=True, ssim of all images will be averaged as a scalar
        win_size: (int, optional): the size of gauss kernel
        win_sigma: (float, optional): sigma of normal distribution
        win (torch.Tensor, optional): 1-D gauss kernel. if None, a new kernel will be created according to win_size and win_sigma
        weights (list, optional): weights for different levels
        K (list or tuple, optional): scalar constants (K1, K2). Try a larger K2 constant (e.g. 0.4) if you get a negative or NaN results.
    Returns:
        torch.Tensor: ms-ssim results
    """
    if not img1.shape == img2.shape:
        raise ValueError("Input images should have the same dimensions.")

    # for d in range(len(img1.shape) - 1, 1, -1):
    #     img1 = img1.squeeze(dim=d)
    #     img2 = img2.squeeze(dim=d)

    if not img1.dtype == img2.dtype:
        raise ValueError("Input images should have the same dtype.")

    if len(img1.shape) == 4:
        avg_pool = F.avg_pool2d
    elif len(img1.shape) == 5:
        avg_pool = F.avg_pool3d
    else:
        raise ValueError(f"Input images should be 4-d or 5-d tensors, but got {img1.shape}")

    smaller_side = min(img1.shape[-2:])

    assert smaller_side > (window_size - 1) * (2 ** 4), "Image size should be larger than %d due to the 4 downsamplings " \
                                                        "with window_size %d in ms-ssim" % ((window_size - 1) * (2 ** 4),window_size)

    if weights is None:
        weights = [0.0448, 0.2856, 0.3001, 0.2363, 0.1333]
    weights = paddle.to_tensor(weights)

    if window is None:
        window = create_window(window_size, sigma, channel)
    assert window.shape == [channel, 1, window_size, window_size], " window.shape error"

    levels = weights.shape[0] # 5
    mcs = []
    for i in range(levels):
        ssim_per_channel, cs =  _ssim(img1, img2, window=window, window_size=window_size,
                                       channel=3, data_range=data_range,C=C, size_average=False)
        if i < levels - 1:
            mcs.append(F.relu(cs))
            padding = [s % 2 for s in img1.shape[2:]]
            img1 = avg_pool(img1, kernel_size=2, padding=padding)
            img2 = avg_pool(img2, kernel_size=2, padding=padding)

    ssim_per_channel = F.relu(ssim_per_channel)  # (batch, channel)
    mcs_and_ssim = paddle.stack(mcs + [ssim_per_channel], axis=0)  # (level, batch, channel) 按照等级堆叠
    ms_ssim_val = paddle.prod(mcs_and_ssim ** weights.reshape([-1, 1, 1]), axis=0) # level 相乘
    print(ms_ssim_val.shape)
    if size_average:
        return ms_ssim_val.mean()
    else:
        # 返回各个channel的值
        return ms_ssim_val.flatten(2).mean(1)


class SSIMLoss(paddle.nn.Layer):
   """
   1. 继承paddle.nn.Layer
   """
   def __init__(self, window_size=11, channel=3, data_range=255., sigma=1.5):
       """
       2. 构造函数根据自己的实际算法需求和使用需求进行参数定义即可
       """
       super(SSIMLoss, self).__init__()
       self.data_range = data_range
       self.C = [0.01, 0.03]
       self.window_size = window_size
       self.channel = channel
       self.sigma = sigma
       self.window = create_window(self.window_size, self.sigma, self.channel)
       # print(self.window_size,self.window.shape)
   def forward(self, input, label):
       """
       3. 实现forward函数，forward在调用时会传递两个参数：input和label
           - input：单个或批次训练数据经过模型前向计算输出结果
           - label：单个或批次训练数据对应的标签数据
           接口返回值是一个Tensor，根据自定义的逻辑加和或计算均值后的损失
       """
       # 使用Paddle中相关API自定义的计算逻辑
       # output = xxxxx
       # return output
       return 1-_ssim(input, label,data_range = self.data_range,
                      window = self.window, window_size=self.window_size, channel=3,
                      size_average=True,C=self.C)

class MS_SSIMLoss(paddle.nn.Layer):
   """
   1. 继承paddle.nn.Layer
   """
   def __init__(self,data_range=255., channel=3, window_size=11, sigma=1.5):
       """
       2. 构造函数根据自己的实际算法需求和使用需求进行参数定义即可
       """
       super(MS_SSIMLoss, self).__init__()
       self.data_range = data_range
       self.C = [0.01, 0.03]
       self.window_size = window_size
       self.channel = channel
       self.sigma = sigma
       self.window = create_window(self.window_size, self.sigma, self.channel)
       # print(self.window_size,self.window.shape)
   def forward(self, input, label):
       """
       3. 实现forward函数，forward在调用时会传递两个参数：input和label
           - input：单个或批次训练数据经过模型前向计算输出结果
           - label：单个或批次训练数据对应的标签数据
           接口返回值是一个Tensor，根据自定义的逻辑加和或计算均值后的损失
       """
       # 使用Paddle中相关API自定义的计算逻辑
       # output = xxxxx
       # return output
       return 1-ms_ssim(input, label, data_range=self.data_range,
                      window = self.window, window_size=self.window_size, channel=self.channel,
                      size_average=True,  sigma=self.sigma,
                      weights=None, C=self.C)

class PSNRLoss(paddle.nn.Layer):
   def __init__(self):
       super(PSNRLoss, self).__init__()

   def forward(self, input, label):
       return 100 - 20 * paddle.log10( ((input - label)**2).mean(axis = [1,2,3])**-0.5 )

# %% [markdown]
# # 训练

# %%
# 训练
model = UNet()
model.train()

train_dataset=MyDateset()

# # 需要接续之前的模型重复训练可以取消注释
# param_dict = paddle.load('./model.pdparams')
# model.load_dict(param_dict)

train_dataloader = paddle.io.DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    drop_last=False)

losspsnr = PSNRLoss()
lossfn = SSIMLoss(window_size=3,data_range=1)

max_epoch=1
scheduler = paddle.optimizer.lr.CosineAnnealingDecay(learning_rate=0.001, T_max=max_epoch)
opt = paddle.optimizer.Adam(learning_rate=scheduler, parameters=model.parameters())

now_step=0
for epoch in range(max_epoch):
    for step, data in enumerate(train_dataloader):
        now_step+=1

        img, label = data
        pre = model(img)
        loss1 = lossfn(pre,label).mean()
        loss2 = losspsnr(pre,label).mean()
        loss = (loss1+loss2/100)/2

        loss.backward()
        opt.step()
        opt.clear_gradients()
        if now_step%10==0:
            print("epoch: {}, batch: {}, loss is: {}".format(epoch, step, loss.mean().numpy()))

paddle.save(model.state_dict(), 'model.pdparams')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_115732/1158051848.py in <module>
#      28
#      29         img, label = data
# ---> 30         pre = model(img)
#      31         loss1 = lossfn(pre,label).mean()
#      32         loss2 = losspsnr(pre,label).mean()
#
# /jinx/tools/yes/lib/python3.9/site-packages/paddle/nn/layer/layers.py in __call__(self, *inputs, **kwargs)
#    1252         ):
#    1253             self._build_once(*inputs, **kwargs)
# -> 1254             return self.forward(*inputs, **kwargs)
#    1255         else:
#    1256             return self._dygraph_call_func(*inputs, **kwargs)
#
# /tmp/ipykernel_115732/3798142722.py in forward(self, inputs)
#      99         x = self.up4(x4, x)
#     100         x = self.up3(x3, x)
# --> 101         x = self.up2(x2, x)
#     102         x = self.up1(x1, x)
#     103
#
# /jinx/tools/yes/lib/python3.9/site-packages/paddle/nn/layer/layers.py in __call__(self, *inputs, **kwargs)
#    1252         ):
#    1253             self._build_once(*inputs, **kwargs)
# -> 1254             return self.forward(*inputs, **kwargs)
#    1255         else:
#    1256             return self._dygraph_call_func(*inputs, **kwargs)
#
# /tmp/ipykernel_115732/3798142722.py in forward(self, input_conv, input_pool)
#      58         x = pad(x)                                #以下采样保存的feature map为基准，填充上采样的feature map尺寸
#      59         x = paddle.concat(x=[input_conv,x],axis=1)#考虑上下文信息，in_channels扩大两倍
# ---> 60         x = self.conv1(x)
#      61         x = self.bn1(x)
#      62         x = self.conv2(x)
#
# /jinx/tools/yes/lib/python3.9/site-packages/paddle/nn/layer/layers.py in __call__(self, *inputs, **kwargs)
#    1252         ):
#    1253             self._build_once(*inputs, **kwargs)
# -> 1254             return self.forward(*inputs, **kwargs)
#    1255         else:
#    1256             return self._dygraph_call_func(*inputs, **kwargs)
#
# /jinx/tools/yes/lib/python3.9/site-packages/paddle/nn/layer/conv.py in forward(self, x)
#     708             )
#     709
# --> 710         out = F.conv._conv_nd(
#     711             x,
#     712             self.weight,
#
# /jinx/tools/yes/lib/python3.9/site-packages/paddle/nn/functional/conv.py in _conv_nd(x, weight, bias, stride, padding, padding_algorithm, dilation, groups, data_format, channel_dim, op_type, use_cudnn, use_mkldnn, name)
#     131     # Due to the poor performance of NHWC, we transpose the input to NCHW.
#     132     if in_dynamic_mode() and op_type == "conv2d":
# --> 133         pre_bias = _C_ops.conv2d(
#     134             x,
#     135             weight,
#
# KeyboardInterrupt:
